# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_table('datasetfinal.txt', sep='\t')
df
# Out:
#       Score  Time Result
# 0        50    60     D-
# 1        51    60     D-
# 2        52    60     D-
# 3        53    60     D-
# 4        54    60     D-
# ...     ...   ...    ...
# 1882     96    24     A+
# 1883     97    24     A+
# 1884     98    24     A+
# 1885     99    24     A+
# 1886    100    24     A+
#
# [1887 rows x 3 columns]

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
model = tree.DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Score','Time']],df['Result'],train_size=0.99)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
model.score(X_train, y_train)
# Out:
# 1.0

# %%
df2=pd.read_excel('datatest.xlsx')

# %%
X_test=df2[['Score','Time']]

# %%
data=model.predict(X_test)

# %%
X_test
# Out:
#       Score  Time
# 0        84    43
# 1        87    52
# 2        79    34
# 3        87    37
# 4        94    57
# ...     ...   ...
# 7727     59    58
# 7728     81    47
# 7729     66    36
# 7730     77    43
# 7731     71    32
#
# [7732 rows x 2 columns]

# %%
#model.score(X_test, y_test)

# %%
data
# Out:
# array(['B', 'B', 'B+', ..., 'C+', 'B-', 'B'], dtype=object)

# %%
a=df2

# %%
a1=pd.DataFrame(np.array(data).T, index=X_test.index)

# %%
a['result']=a1

# %%
a
# Out:
#         ID  Score  Time result
# 0        1     84    43      B
# 1        2     87    52      B
# 2        3     79    34     B+
# 3        4     87    37     A-
# 4        5     94    57     B+
# ...    ...    ...   ...    ...
# 7727  7728     59    58      D
# 7728  7729     81    47     B-
# 7729  7730     66    36     C+
# 7730  7731     77    43     B-
# 7731  7732     71    32      B
#
# [7732 rows x 4 columns]

# %%
#a.to_csv(index=False)

# %%
a.to_csv('exa.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-bde9d798cb62> in <module>
# ----> 1 a.to_csv('exa.csv',index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
import sqlite3

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///E:\\school.db', echo=False)

# %%
a.to_sql('test', con=engine)

# %%
engine.execute('SELECT * FROM test').fetchall()
# Out:
# [(0, 1, 84, 43, 'B'),
#  (1, 2, 87, 52, 'B'),
#  (2, 3, 79, 34, 'B+'),
#  (3, 4, 87, 37, 'A-'),
#  (4, 5, 94, 57, 'B+'),
#  (5, 6, 66, 27, 'B-'),
#  (6, 7, 50, 33, 'C-'),
#  (7, 8, 51, 35, 'C-'),
#  (8, 9, 80, 28, 'A-'),
#  (9, 10, 81, 24, 'A-'),
#  (10, 11, 78, 26, 'B+'),
#  (11, 12, 75, 49, 'C+'),
#  (12, 13, 99, 44, 'A-'),
#  (13, 14, 87, 56, 'B'),
#  (14, 15, 59, 26, 'C'),
#  (15, 16, 76, 51, 'C+'),
#  (16, 17, 54, 25, 'C-'),
#  (17, 18, 76, 26, 'B+'),
#  (18, 19, 80, 34, 'A-'),
#  (19, 20, 55, 42, 'D+'),
#  (20, 21, 98, 24, 'A+'),
#  (21, 22, 88, 33, 'A'),
#  (22, 23, 85, 37, 'A-'),
#  (23, 24, 57, 44, 'D+'),
#  (24, 25, 61, 55, 'D+'),
#  (25, 26, 58, 32, 'C'),
#  (26, 27, 64, 45, 'C-'),
#  (27, 28, 67, 28, 'B-'),
#  (28, 29, 98, 24, 'A+'),
#  (29, 30, 75, 59, 'C+'),
#  (30, 31, 68, 33, 'B-'),
#  (31, 32, 93, 32, 'A+'),
#  (32, 33, 73, 34, 'B'),
#  (33, 34, 85, 36, 'A-'),
#  (34, 35, 78, 25, 'B+'),
#  (35, 36, 51, 30, 'C-'),
#  (36, 37, 53, 54, 'D-'),
#  (37, 38, 87, 27, 'A'),
# ...

# %%
engine
# Out:
# Engine(sqlite:///E:\school.db)
